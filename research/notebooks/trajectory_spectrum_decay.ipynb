# %% [markdown]
# # Trajectory Covariance Spectrum Decay
#
# This notebook analyzes each latent trajectory as a matrix of shape `(L, D)`.
#
# For each trajectory it:
# 1. extracts the response or reasoning-span latent sequence,
# 2. computes the token-wise covariance matrix over latent dimensions,
# 3. computes the covariance eigenspectrum,
# 4. estimates a **power-law decay exponent** from the slope of `log(eigenvalue)` vs `log(rank)`,
# 5. plots success vs decay rate in 2D.
#
# Interpretation idea:
# - larger power-law exponent means the spectrum decays faster,
# - smaller exponent means variance is spread across more directions.

# %%
from pathlib import Path
import json
import random

import matplotlib.pyplot as plt
import numpy as np
import torch

from research.buffer import ParquetLatentBuffer
from research.latent.codec import deserialize_latent_tensor

OUTPUT_DIR = Path('/workspace/outputs/offline_math500_temp1_k32/qwen_qwen3_4b')
USE_REASONING_SPAN = True
RANDOM_SEED = 1
MAX_COMPONENTS = 64
MIN_SEQ_LEN = 4
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)


def load_jsonl(path: Path):
    rows = []
    with path.open(encoding='utf-8') as f:
        for line in f:
            if line.strip():
                rows.append(json.loads(line))
    return rows

metadata_path = OUTPUT_DIR / 'metadata.jsonl'
buffer_dir = OUTPUT_DIR / 'buffer'
summary_path = OUTPUT_DIR / 'collection_summary.json'

assert metadata_path.exists(), f'missing metadata: {metadata_path}'
assert buffer_dir.exists(), f'missing buffer: {buffer_dir}'

metadata_rows = load_jsonl(metadata_path)
metadata_by_uid = {row['uid']: row for row in metadata_rows}
print(f'Loaded {len(metadata_rows)} metadata rows from {metadata_path}')
if summary_path.exists():
    print(summary_path.read_text(encoding='utf-8'))
# Out:
# Loaded 3200 metadata rows from /workspace/outputs/offline_math500_temp1_k32/qwen_qwen3_4b/metadata.jsonl
# {
#   "model": "Qwen/Qwen3-4B",
#   "input": "/workspace/data/math500_local_qwen_qwen3_4b.jsonl",
#   "output_dir": "/workspace/outputs/offline_math500_temp1_k32/qwen_qwen3_4b",
#   "buffer_dir": "/workspace/outputs/offline_math500_temp1_k32/qwen_qwen3_4b/buffer",
#   "metadata_path": "/workspace/outputs/offline_math500_temp1_k32/qwen_qwen3_4b/metadata.jsonl",
#   "processed_examples": 100,
#   "saved_questions": 100,
#   "saved_sequences": 3200,
#   "skipped_existing_sequences": 0,
#   "num_samples_per_question": 32,
#   "temperature": 1.0,
#   "seed": 1,
#   "resume": true,
#   "layer_index": -1,
#   "latent_dtype": "fp16",
#   "device": "cuda",
#   "buffer_stats": {
#     "buffer/total_samples": 3200,
#     "buffer/total_shards": 3200,
#     "buffer/pending_rows": 0
#   }
# }

# %%
buffer = ParquetLatentBuffer(
    root_dir=str(buffer_dir),
    shard_max_samples=256,
    compression='zstd',
    max_disk_gb=1000.0,
)
rows = list(buffer.iter_rows())
rows = [row for row in rows if row['uid'] in metadata_by_uid]
print(f'Loaded {len(rows)} latent rows from buffer')
print('Buffer stats:', buffer.get_stats())
# Out:
# Loaded 3200 latent rows from buffer
# Buffer stats: {'buffer/total_samples': 3200, 'buffer/total_shards': 3200, 'buffer/pending_rows': 0}

# %%
def extract_sequence_for_analysis(row, meta, use_reasoning_span=True):
    seq = deserialize_latent_tensor(
        row['latent_blob'],
        seq_len=int(row['response_length']),
        hidden_dim=int(row['hidden_dim']),
        dtype=str(row['dtype']),
    ).float()

    start = 0
    end = seq.shape[0]
    if use_reasoning_span and meta.get('think_token_start') is not None and meta.get('think_token_end') is not None:
        start = int(meta['think_token_start'])
        end = int(meta['think_token_end'])
        start = max(0, min(start, seq.shape[0]))
        end = max(start + 1, min(end, seq.shape[0]))
    return seq[start:end]


def covariance_eigenspectrum(seq):
    x = seq.numpy().astype(np.float64)
    x = x - x.mean(axis=0, keepdims=True)
    if x.shape[0] < 2:
        return None
    cov = (x.T @ x) / max(1, x.shape[0] - 1)
    eigvals = np.linalg.eigvalsh(cov)
    eigvals = np.sort(eigvals)[::-1]
    eigvals = np.clip(eigvals, 1e-12, None)
    return eigvals


def estimate_powerlaw_exponent(eigvals, max_components=256):
    eigvals = np.asarray(eigvals, dtype=np.float64)
    k = min(len(eigvals), max_components)
    if k < 3:
        return None
    ranks = np.arange(1, k + 1, dtype=np.float64)
    x = np.log(ranks)
    y = np.log(eigvals[:k])
    slope, intercept = np.polyfit(x, y, deg=1)
    return float(-slope)

samples = []
for row in rows:
    meta = metadata_by_uid[row['uid']]
    seq = extract_sequence_for_analysis(row, meta, use_reasoning_span=USE_REASONING_SPAN)
    if seq.shape[0] < MIN_SEQ_LEN:
        continue
    eigvals = covariance_eigenspectrum(seq)
    if eigvals is None:
        continue
    decay_rate = estimate_powerlaw_exponent(eigvals, max_components=MAX_COMPONENTS)
    if decay_rate is None:
        continue
    samples.append({
        'uid': row['uid'],
        'question_uid': meta.get('question_uid', meta['uid']),
        'sample_idx': int(meta.get('sample_idx', 0)),
        'success': bool(meta['success']),
        'score_accuracy': float(meta['score_accuracy']),
        'response_length': int(meta['response_length']),
        'analysis_length': int(seq.shape[0]),
        'decay_rate': decay_rate,
        'top_eigvals': eigvals[:10],
        'question': meta['question'],
        'response': meta['response'],
    })
    print(f"Sample {len(samples)}: uid={row['uid']}, question_uid={meta.get('question_uid', meta['uid'])}, "
          f"success={meta['success']}, score_accuracy={meta['score_accuracy']:.2f}, response_length={meta['response_length']}, analysis_length={seq.shape[0]}, decay_rate={decay_rate:.2f}")

print(f'Prepared {len(samples)} samples with valid eigenspectra')
# Out:
# Sample 1: uid=test/precalculus/807.json::sample_00, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=223, analysis_length=223, decay_rate=1.00
# Sample 2: uid=test/precalculus/807.json::sample_01, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=190, analysis_length=190, decay_rate=0.98
# Sample 3: uid=test/precalculus/807.json::sample_02, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=219, analysis_length=219, decay_rate=1.01
# Sample 4: uid=test/precalculus/807.json::sample_03, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=231, analysis_length=231, decay_rate=0.99
# Sample 5: uid=test/precalculus/807.json::sample_04, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=212, analysis_length=212, decay_rate=0.99
# Sample 6: uid=test/precalculus/807.json::sample_05, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=203, analysis_length=203, decay_rate=0.98
# Sample 7: uid=test/precalculus/807.json::sample_06, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=206, analysis_length=206, decay_rate=0.96
# Sample 8: uid=test/precalculus/807.json::sample_07, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=221, analysis_length=221, decay_rate=0.98
# Sample 9: uid=test/precalculus/807.json::sample_08, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=272, analysis_length=272, decay_rate=0.99
# Sample 10: uid=test/precalculus/807.json::sample_09, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=232, analysis_length=232, decay_rate=0.99
# Sample 11: uid=test/precalculus/807.json::sample_10, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=257, analysis_length=257, decay_rate=1.00
# Sample 12: uid=test/precalculus/807.json::sample_11, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=191, analysis_length=191, decay_rate=0.99
# Sample 13: uid=test/precalculus/807.json::sample_12, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=199, analysis_length=199, decay_rate=1.01
# Sample 14: uid=test/precalculus/807.json::sample_13, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=238, analysis_length=238, decay_rate=0.98
# Sample 15: uid=test/precalculus/807.json::sample_14, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=244, analysis_length=244, decay_rate=0.95
# Sample 16: uid=test/precalculus/807.json::sample_15, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=251, analysis_length=251, decay_rate=0.98
# Sample 17: uid=test/precalculus/807.json::sample_16, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=218, analysis_length=218, decay_rate=1.00
# Sample 18: uid=test/precalculus/807.json::sample_17, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=206, analysis_length=206, decay_rate=0.97
# Sample 19: uid=test/precalculus/807.json::sample_18, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=208, analysis_length=208, decay_rate=0.99
# Sample 20: uid=test/precalculus/807.json::sample_19, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=200, analysis_length=200, decay_rate=0.99
# Sample 21: uid=test/precalculus/807.json::sample_20, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=190, analysis_length=190, decay_rate=0.99
# Sample 22: uid=test/precalculus/807.json::sample_21, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=215, analysis_length=215, decay_rate=1.01
# Sample 23: uid=test/precalculus/807.json::sample_22, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=229, analysis_length=229, decay_rate=0.99
# Sample 24: uid=test/precalculus/807.json::sample_23, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=193, analysis_length=193, decay_rate=1.00
# Sample 25: uid=test/precalculus/807.json::sample_24, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=227, analysis_length=227, decay_rate=0.98
# Sample 26: uid=test/precalculus/807.json::sample_25, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=210, analysis_length=210, decay_rate=1.01
# Sample 27: uid=test/precalculus/807.json::sample_26, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=187, analysis_length=187, decay_rate=0.99
# Sample 28: uid=test/precalculus/807.json::sample_27, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=188, analysis_length=188, decay_rate=0.98
# Sample 29: uid=test/precalculus/807.json::sample_28, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=250, analysis_length=250, decay_rate=1.01
# Sample 30: uid=test/precalculus/807.json::sample_29, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=201, analysis_length=201, decay_rate=0.98
# Sample 31: uid=test/precalculus/807.json::sample_30, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=221, analysis_length=221, decay_rate=0.99
# Sample 32: uid=test/precalculus/807.json::sample_31, question_uid=test/precalculus/807.json, success=True, score_accuracy=1.00, response_length=190, analysis_length=190, decay_rate=0.99
# Sample 33: uid=test/intermediate_algebra/1994.json::sample_00, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=673, analysis_length=673, decay_rate=1.20
# Sample 34: uid=test/intermediate_algebra/1994.json::sample_01, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=709, analysis_length=709, decay_rate=1.21
# Sample 35: uid=test/intermediate_algebra/1994.json::sample_02, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=906, analysis_length=906, decay_rate=1.20
# Sample 36: uid=test/intermediate_algebra/1994.json::sample_03, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=697, analysis_length=697, decay_rate=1.23
# Sample 37: uid=test/intermediate_algebra/1994.json::sample_04, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=705, analysis_length=705, decay_rate=1.20
# Sample 38: uid=test/intermediate_algebra/1994.json::sample_05, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=740, analysis_length=740, decay_rate=1.16
# Sample 39: uid=test/intermediate_algebra/1994.json::sample_06, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=569, analysis_length=569, decay_rate=1.16
# Sample 40: uid=test/intermediate_algebra/1994.json::sample_07, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=734, analysis_length=734, decay_rate=1.20
# Sample 41: uid=test/intermediate_algebra/1994.json::sample_08, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=737, analysis_length=737, decay_rate=1.20
# Sample 42: uid=test/intermediate_algebra/1994.json::sample_09, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=776, analysis_length=776, decay_rate=1.17
# Sample 43: uid=test/intermediate_algebra/1994.json::sample_10, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=752, analysis_length=752, decay_rate=1.19
# Sample 44: uid=test/intermediate_algebra/1994.json::sample_11, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=649, analysis_length=649, decay_rate=1.21
# Sample 45: uid=test/intermediate_algebra/1994.json::sample_12, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=737, analysis_length=737, decay_rate=1.19
# Sample 46: uid=test/intermediate_algebra/1994.json::sample_13, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=683, analysis_length=683, decay_rate=1.21
# Sample 47: uid=test/intermediate_algebra/1994.json::sample_14, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=864, analysis_length=864, decay_rate=1.22
# Sample 48: uid=test/intermediate_algebra/1994.json::sample_15, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=719, analysis_length=719, decay_rate=1.20
# Sample 49: uid=test/intermediate_algebra/1994.json::sample_16, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=684, analysis_length=684, decay_rate=1.19
# Sample 50: uid=test/intermediate_algebra/1994.json::sample_17, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=999, analysis_length=999, decay_rate=1.19
# Sample 51: uid=test/intermediate_algebra/1994.json::sample_18, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=670, analysis_length=670, decay_rate=1.19
# Sample 52: uid=test/intermediate_algebra/1994.json::sample_19, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=731, analysis_length=731, decay_rate=1.16
# Sample 53: uid=test/intermediate_algebra/1994.json::sample_20, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=734, analysis_length=734, decay_rate=1.21
# Sample 54: uid=test/intermediate_algebra/1994.json::sample_21, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=625, analysis_length=625, decay_rate=1.17
# Sample 55: uid=test/intermediate_algebra/1994.json::sample_22, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=554, analysis_length=554, decay_rate=1.15
# Sample 56: uid=test/intermediate_algebra/1994.json::sample_23, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=723, analysis_length=723, decay_rate=1.16
# Sample 57: uid=test/intermediate_algebra/1994.json::sample_24, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=672, analysis_length=672, decay_rate=1.20
# Sample 58: uid=test/intermediate_algebra/1994.json::sample_25, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=745, analysis_length=745, decay_rate=1.18
# Sample 59: uid=test/intermediate_algebra/1994.json::sample_26, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=691, analysis_length=691, decay_rate=1.17
# Sample 60: uid=test/intermediate_algebra/1994.json::sample_27, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=779, analysis_length=779, decay_rate=1.18
# Sample 61: uid=test/intermediate_algebra/1994.json::sample_28, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=735, analysis_length=735, decay_rate=1.15
# Sample 62: uid=test/intermediate_algebra/1994.json::sample_29, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=651, analysis_length=651, decay_rate=1.15
# Sample 63: uid=test/intermediate_algebra/1994.json::sample_30, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=740, analysis_length=740, decay_rate=1.17
# Sample 64: uid=test/intermediate_algebra/1994.json::sample_31, question_uid=test/intermediate_algebra/1994.json, success=True, score_accuracy=1.00, response_length=721, analysis_length=721, decay_rate=1.19
# Sample 65: uid=test/algebra/2584.json::sample_00, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=336, analysis_length=336, decay_rate=1.19
# Sample 66: uid=test/algebra/2584.json::sample_01, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=336, analysis_length=336, decay_rate=1.19
# Sample 67: uid=test/algebra/2584.json::sample_02, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=341, analysis_length=341, decay_rate=1.19
# Sample 68: uid=test/algebra/2584.json::sample_03, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=402, analysis_length=402, decay_rate=1.19
# Sample 69: uid=test/algebra/2584.json::sample_04, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=379, analysis_length=379, decay_rate=1.18
# Sample 70: uid=test/algebra/2584.json::sample_05, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=341, analysis_length=341, decay_rate=1.19
# Sample 71: uid=test/algebra/2584.json::sample_06, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=375, analysis_length=375, decay_rate=1.19
# Sample 72: uid=test/algebra/2584.json::sample_07, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=337, analysis_length=337, decay_rate=1.19
# Sample 73: uid=test/algebra/2584.json::sample_08, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=337, analysis_length=337, decay_rate=1.19
# Sample 74: uid=test/algebra/2584.json::sample_09, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=338, analysis_length=338, decay_rate=1.19
# Sample 75: uid=test/algebra/2584.json::sample_10, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=336, analysis_length=336, decay_rate=1.19
# Sample 76: uid=test/algebra/2584.json::sample_11, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=373, analysis_length=373, decay_rate=1.18
# Sample 77: uid=test/algebra/2584.json::sample_12, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=374, analysis_length=374, decay_rate=1.18
# Sample 78: uid=test/algebra/2584.json::sample_13, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=372, analysis_length=372, decay_rate=1.18
# Sample 79: uid=test/algebra/2584.json::sample_14, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=336, analysis_length=336, decay_rate=1.19
# Sample 80: uid=test/algebra/2584.json::sample_15, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=396, analysis_length=396, decay_rate=1.18
# Sample 81: uid=test/algebra/2584.json::sample_16, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=383, analysis_length=383, decay_rate=1.18
# Sample 82: uid=test/algebra/2584.json::sample_17, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=369, analysis_length=369, decay_rate=1.19
# Sample 83: uid=test/algebra/2584.json::sample_18, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=335, analysis_length=335, decay_rate=1.19
# Sample 84: uid=test/algebra/2584.json::sample_19, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=358, analysis_length=358, decay_rate=1.18
# Sample 85: uid=test/algebra/2584.json::sample_20, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=353, analysis_length=353, decay_rate=1.20
# Sample 86: uid=test/algebra/2584.json::sample_21, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=367, analysis_length=367, decay_rate=1.19
# Sample 87: uid=test/algebra/2584.json::sample_22, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=377, analysis_length=377, decay_rate=1.17
# Sample 88: uid=test/algebra/2584.json::sample_23, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=360, analysis_length=360, decay_rate=1.18
# Sample 89: uid=test/algebra/2584.json::sample_24, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=374, analysis_length=374, decay_rate=1.19
# Sample 90: uid=test/algebra/2584.json::sample_25, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=382, analysis_length=382, decay_rate=1.19
# Sample 91: uid=test/algebra/2584.json::sample_26, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=349, analysis_length=349, decay_rate=1.19
# Sample 92: uid=test/algebra/2584.json::sample_27, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=362, analysis_length=362, decay_rate=1.18
# Sample 93: uid=test/algebra/2584.json::sample_28, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=377, analysis_length=377, decay_rate=1.18
# Sample 94: uid=test/algebra/2584.json::sample_29, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=353, analysis_length=353, decay_rate=1.19
# Sample 95: uid=test/algebra/2584.json::sample_30, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=336, analysis_length=336, decay_rate=1.19
# Sample 96: uid=test/algebra/2584.json::sample_31, question_uid=test/algebra/2584.json, success=True, score_accuracy=1.00, response_length=372, analysis_length=372, decay_rate=1.18
# Sample 97: uid=test/number_theory/572.json::sample_00, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=333, analysis_length=333, decay_rate=1.03
# Sample 98: uid=test/number_theory/572.json::sample_01, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=284, analysis_length=284, decay_rate=1.04
# Sample 99: uid=test/number_theory/572.json::sample_02, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=347, analysis_length=347, decay_rate=1.03
# Sample 100: uid=test/number_theory/572.json::sample_03, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=278, analysis_length=278, decay_rate=1.04
# Sample 101: uid=test/number_theory/572.json::sample_04, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=340, analysis_length=340, decay_rate=1.01
# Sample 102: uid=test/number_theory/572.json::sample_05, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=321, analysis_length=321, decay_rate=1.00
# Sample 103: uid=test/number_theory/572.json::sample_06, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=330, analysis_length=330, decay_rate=1.02
# Sample 104: uid=test/number_theory/572.json::sample_07, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=326, analysis_length=326, decay_rate=1.02
# Sample 105: uid=test/number_theory/572.json::sample_08, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=309, analysis_length=309, decay_rate=1.04
# Sample 106: uid=test/number_theory/572.json::sample_09, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=292, analysis_length=292, decay_rate=1.02
# Sample 107: uid=test/number_theory/572.json::sample_10, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=292, analysis_length=292, decay_rate=1.03
# Sample 108: uid=test/number_theory/572.json::sample_11, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=303, analysis_length=303, decay_rate=1.02
# Sample 109: uid=test/number_theory/572.json::sample_12, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=292, analysis_length=292, decay_rate=1.01
# Sample 110: uid=test/number_theory/572.json::sample_13, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=333, analysis_length=333, decay_rate=1.03
# Sample 111: uid=test/number_theory/572.json::sample_14, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=275, analysis_length=275, decay_rate=1.02
# Sample 112: uid=test/number_theory/572.json::sample_15, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=329, analysis_length=329, decay_rate=1.01
# Sample 113: uid=test/number_theory/572.json::sample_16, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=356, analysis_length=356, decay_rate=1.01
# Sample 114: uid=test/number_theory/572.json::sample_17, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=303, analysis_length=303, decay_rate=1.03
# Sample 115: uid=test/number_theory/572.json::sample_18, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=329, analysis_length=329, decay_rate=1.02
# Sample 116: uid=test/number_theory/572.json::sample_19, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=279, analysis_length=279, decay_rate=1.06
# Sample 117: uid=test/number_theory/572.json::sample_20, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=334, analysis_length=334, decay_rate=1.02
# Sample 118: uid=test/number_theory/572.json::sample_21, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=358, analysis_length=358, decay_rate=1.02
# Sample 119: uid=test/number_theory/572.json::sample_22, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=289, analysis_length=289, decay_rate=1.05
# Sample 120: uid=test/number_theory/572.json::sample_23, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=326, analysis_length=326, decay_rate=1.01
# Sample 121: uid=test/number_theory/572.json::sample_24, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=294, analysis_length=294, decay_rate=1.04
# Sample 122: uid=test/number_theory/572.json::sample_25, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=340, analysis_length=340, decay_rate=1.02
# Sample 123: uid=test/number_theory/572.json::sample_26, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=312, analysis_length=312, decay_rate=1.04
# Sample 124: uid=test/number_theory/572.json::sample_27, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=312, analysis_length=312, decay_rate=1.02
# Sample 125: uid=test/number_theory/572.json::sample_28, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=327, analysis_length=327, decay_rate=1.03
# Sample 126: uid=test/number_theory/572.json::sample_29, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=337, analysis_length=337, decay_rate=1.01
# Sample 127: uid=test/number_theory/572.json::sample_30, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=304, analysis_length=304, decay_rate=1.03
# Sample 128: uid=test/number_theory/572.json::sample_31, question_uid=test/number_theory/572.json, success=True, score_accuracy=1.00, response_length=317, analysis_length=317, decay_rate=1.04
# Sample 129: uid=test/algebra/1349.json::sample_00, question_uid=test/algebra/1349.json, success=False, score_accuracy=0.00, response_length=405, analysis_length=405, decay_rate=1.08
# Sample 130: uid=test/algebra/1349.json::sample_01, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=661, analysis_length=661, decay_rate=1.09
# Sample 131: uid=test/algebra/1349.json::sample_02, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=559, analysis_length=559, decay_rate=1.07
# Sample 132: uid=test/algebra/1349.json::sample_03, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=706, analysis_length=706, decay_rate=1.08
# Sample 133: uid=test/algebra/1349.json::sample_04, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=577, analysis_length=577, decay_rate=1.09
# Sample 134: uid=test/algebra/1349.json::sample_05, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=542, analysis_length=542, decay_rate=1.07
# Sample 135: uid=test/algebra/1349.json::sample_06, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=696, analysis_length=696, decay_rate=1.10
# Sample 136: uid=test/algebra/1349.json::sample_07, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=643, analysis_length=643, decay_rate=1.07
# Sample 137: uid=test/algebra/1349.json::sample_08, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=489, analysis_length=489, decay_rate=1.05
# Sample 138: uid=test/algebra/1349.json::sample_09, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=548, analysis_length=548, decay_rate=1.09
# Sample 139: uid=test/algebra/1349.json::sample_10, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=695, analysis_length=695, decay_rate=1.07
# Sample 140: uid=test/algebra/1349.json::sample_11, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=775, analysis_length=775, decay_rate=1.09
# Sample 141: uid=test/algebra/1349.json::sample_12, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=577, analysis_length=577, decay_rate=1.07
# Sample 142: uid=test/algebra/1349.json::sample_13, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=604, analysis_length=604, decay_rate=1.06
# Sample 143: uid=test/algebra/1349.json::sample_14, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=625, analysis_length=625, decay_rate=1.11
# Sample 144: uid=test/algebra/1349.json::sample_15, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=572, analysis_length=572, decay_rate=1.07
# Sample 145: uid=test/algebra/1349.json::sample_16, question_uid=test/algebra/1349.json, success=False, score_accuracy=0.00, response_length=273, analysis_length=273, decay_rate=1.11
# Sample 146: uid=test/algebra/1349.json::sample_17, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=730, analysis_length=730, decay_rate=1.09
# Sample 147: uid=test/algebra/1349.json::sample_18, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=650, analysis_length=650, decay_rate=1.06
# Sample 148: uid=test/algebra/1349.json::sample_19, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=642, analysis_length=642, decay_rate=1.08
# Sample 149: uid=test/algebra/1349.json::sample_20, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=606, analysis_length=606, decay_rate=1.09
# Sample 150: uid=test/algebra/1349.json::sample_21, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=915, analysis_length=915, decay_rate=1.11
# Sample 151: uid=test/algebra/1349.json::sample_22, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=555, analysis_length=555, decay_rate=1.11
# Sample 152: uid=test/algebra/1349.json::sample_23, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=927, analysis_length=927, decay_rate=1.08
# Sample 153: uid=test/algebra/1349.json::sample_24, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=562, analysis_length=562, decay_rate=1.05
# Sample 154: uid=test/algebra/1349.json::sample_25, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=840, analysis_length=840, decay_rate=1.08
# Sample 155: uid=test/algebra/1349.json::sample_26, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=1167, analysis_length=1167, decay_rate=1.10
# Sample 156: uid=test/algebra/1349.json::sample_27, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=551, analysis_length=551, decay_rate=1.03
# Sample 157: uid=test/algebra/1349.json::sample_28, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=837, analysis_length=837, decay_rate=1.09
# Sample 158: uid=test/algebra/1349.json::sample_29, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=575, analysis_length=575, decay_rate=1.08
# Sample 159: uid=test/algebra/1349.json::sample_30, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=669, analysis_length=669, decay_rate=1.07
# Sample 160: uid=test/algebra/1349.json::sample_31, question_uid=test/algebra/1349.json, success=True, score_accuracy=1.00, response_length=554, analysis_length=554, decay_rate=1.10
# Sample 161: uid=test/prealgebra/1622.json::sample_00, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=350, analysis_length=350, decay_rate=1.08
# Sample 162: uid=test/prealgebra/1622.json::sample_01, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=283, analysis_length=283, decay_rate=1.11
# Sample 163: uid=test/prealgebra/1622.json::sample_02, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=342, analysis_length=342, decay_rate=1.09
# Sample 164: uid=test/prealgebra/1622.json::sample_03, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=285, analysis_length=285, decay_rate=1.07
# Sample 165: uid=test/prealgebra/1622.json::sample_04, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=404, analysis_length=404, decay_rate=1.11
# Sample 166: uid=test/prealgebra/1622.json::sample_05, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=283, analysis_length=283, decay_rate=1.07
# Sample 167: uid=test/prealgebra/1622.json::sample_06, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=366, analysis_length=366, decay_rate=1.08
# Sample 168: uid=test/prealgebra/1622.json::sample_07, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=348, analysis_length=348, decay_rate=1.12
# Sample 169: uid=test/prealgebra/1622.json::sample_08, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=322, analysis_length=322, decay_rate=1.10
# Sample 170: uid=test/prealgebra/1622.json::sample_09, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=332, analysis_length=332, decay_rate=1.10
# Sample 171: uid=test/prealgebra/1622.json::sample_10, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=305, analysis_length=305, decay_rate=1.05
# Sample 172: uid=test/prealgebra/1622.json::sample_11, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=329, analysis_length=329, decay_rate=1.12
# Sample 173: uid=test/prealgebra/1622.json::sample_12, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=348, analysis_length=348, decay_rate=1.11
# Sample 174: uid=test/prealgebra/1622.json::sample_13, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=238, analysis_length=238, decay_rate=1.08
# Sample 175: uid=test/prealgebra/1622.json::sample_14, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=307, analysis_length=307, decay_rate=1.10
# Sample 176: uid=test/prealgebra/1622.json::sample_15, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=351, analysis_length=351, decay_rate=1.08
# Sample 177: uid=test/prealgebra/1622.json::sample_16, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=326, analysis_length=326, decay_rate=1.07
# Sample 178: uid=test/prealgebra/1622.json::sample_17, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=198, analysis_length=198, decay_rate=1.04
# Sample 179: uid=test/prealgebra/1622.json::sample_18, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=256, analysis_length=256, decay_rate=1.05
# Sample 180: uid=test/prealgebra/1622.json::sample_19, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=290, analysis_length=290, decay_rate=1.07
# Sample 181: uid=test/prealgebra/1622.json::sample_20, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=283, analysis_length=283, decay_rate=1.06
# Sample 182: uid=test/prealgebra/1622.json::sample_21, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=353, analysis_length=353, decay_rate=1.08
# Sample 183: uid=test/prealgebra/1622.json::sample_22, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=344, analysis_length=344, decay_rate=1.11
# Sample 184: uid=test/prealgebra/1622.json::sample_23, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=335, analysis_length=335, decay_rate=1.11
# Sample 185: uid=test/prealgebra/1622.json::sample_24, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=290, analysis_length=290, decay_rate=1.05
# Sample 186: uid=test/prealgebra/1622.json::sample_25, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=280, analysis_length=280, decay_rate=1.08
# Sample 187: uid=test/prealgebra/1622.json::sample_26, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=296, analysis_length=296, decay_rate=1.05
# Sample 188: uid=test/prealgebra/1622.json::sample_27, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=333, analysis_length=333, decay_rate=1.06
# Sample 189: uid=test/prealgebra/1622.json::sample_28, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=262, analysis_length=262, decay_rate=1.05
# Sample 190: uid=test/prealgebra/1622.json::sample_29, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=365, analysis_length=365, decay_rate=1.09
# Sample 191: uid=test/prealgebra/1622.json::sample_30, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=429, analysis_length=429, decay_rate=1.14
# Sample 192: uid=test/prealgebra/1622.json::sample_31, question_uid=test/prealgebra/1622.json, success=True, score_accuracy=1.00, response_length=296, analysis_length=296, decay_rate=1.08
# Sample 193: uid=test/number_theory/515.json::sample_00, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=477, analysis_length=477, decay_rate=1.10
# Sample 194: uid=test/number_theory/515.json::sample_01, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=358, analysis_length=358, decay_rate=1.05
# Sample 195: uid=test/number_theory/515.json::sample_02, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=739, analysis_length=739, decay_rate=1.10
# Sample 196: uid=test/number_theory/515.json::sample_03, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=562, analysis_length=562, decay_rate=1.10
# Sample 197: uid=test/number_theory/515.json::sample_04, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=345, analysis_length=345, decay_rate=1.06
# Sample 198: uid=test/number_theory/515.json::sample_05, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=398, analysis_length=398, decay_rate=1.08
# Sample 199: uid=test/number_theory/515.json::sample_06, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=626, analysis_length=626, decay_rate=1.13
# Sample 200: uid=test/number_theory/515.json::sample_07, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=429, analysis_length=429, decay_rate=1.07
# Sample 201: uid=test/number_theory/515.json::sample_08, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=457, analysis_length=457, decay_rate=1.09
# Sample 202: uid=test/number_theory/515.json::sample_09, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=478, analysis_length=478, decay_rate=1.12
# Sample 203: uid=test/number_theory/515.json::sample_10, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=386, analysis_length=386, decay_rate=1.08
# Sample 204: uid=test/number_theory/515.json::sample_11, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=572, analysis_length=572, decay_rate=1.09
# Sample 205: uid=test/number_theory/515.json::sample_12, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=385, analysis_length=385, decay_rate=1.08
# Sample 206: uid=test/number_theory/515.json::sample_13, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=449, analysis_length=449, decay_rate=1.08
# Sample 207: uid=test/number_theory/515.json::sample_14, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=410, analysis_length=410, decay_rate=1.07
# Sample 208: uid=test/number_theory/515.json::sample_15, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=352, analysis_length=352, decay_rate=1.06
# Sample 209: uid=test/number_theory/515.json::sample_16, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=354, analysis_length=354, decay_rate=1.07
# Sample 210: uid=test/number_theory/515.json::sample_17, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=375, analysis_length=375, decay_rate=1.04
# Sample 211: uid=test/number_theory/515.json::sample_18, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=479, analysis_length=479, decay_rate=1.09
# Sample 212: uid=test/number_theory/515.json::sample_19, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=345, analysis_length=345, decay_rate=1.09
# Sample 213: uid=test/number_theory/515.json::sample_20, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=352, analysis_length=352, decay_rate=1.08
# Sample 214: uid=test/number_theory/515.json::sample_21, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=418, analysis_length=418, decay_rate=1.08
# Sample 215: uid=test/number_theory/515.json::sample_22, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=465, analysis_length=465, decay_rate=1.08
# Sample 216: uid=test/number_theory/515.json::sample_23, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=356, analysis_length=356, decay_rate=1.09
# Sample 217: uid=test/number_theory/515.json::sample_24, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=432, analysis_length=432, decay_rate=1.08
# Sample 218: uid=test/number_theory/515.json::sample_25, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=353, analysis_length=353, decay_rate=1.06
# Sample 219: uid=test/number_theory/515.json::sample_26, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=523, analysis_length=523, decay_rate=1.10
# Sample 220: uid=test/number_theory/515.json::sample_27, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=413, analysis_length=413, decay_rate=1.09
# Sample 221: uid=test/number_theory/515.json::sample_28, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=366, analysis_length=366, decay_rate=1.06
# Sample 222: uid=test/number_theory/515.json::sample_29, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=327, analysis_length=327, decay_rate=1.09
# Sample 223: uid=test/number_theory/515.json::sample_30, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=484, analysis_length=484, decay_rate=1.12
# Sample 224: uid=test/number_theory/515.json::sample_31, question_uid=test/number_theory/515.json, success=True, score_accuracy=1.00, response_length=500, analysis_length=500, decay_rate=1.09
# Sample 225: uid=test/precalculus/927.json::sample_00, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=650, analysis_length=650, decay_rate=1.09
# Sample 226: uid=test/precalculus/927.json::sample_01, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=693, analysis_length=693, decay_rate=1.06
# Sample 227: uid=test/precalculus/927.json::sample_02, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=592, analysis_length=592, decay_rate=1.08
# Sample 228: uid=test/precalculus/927.json::sample_03, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=842, analysis_length=842, decay_rate=1.08
# Sample 229: uid=test/precalculus/927.json::sample_04, question_uid=test/precalculus/927.json, success=False, score_accuracy=0.00, response_length=782, analysis_length=782, decay_rate=1.05
# Sample 230: uid=test/precalculus/927.json::sample_05, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=624, analysis_length=624, decay_rate=1.08
# Sample 231: uid=test/precalculus/927.json::sample_06, question_uid=test/precalculus/927.json, success=False, score_accuracy=0.00, response_length=1470, analysis_length=1470, decay_rate=1.10
# Sample 232: uid=test/precalculus/927.json::sample_07, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=604, analysis_length=604, decay_rate=1.06
# Sample 233: uid=test/precalculus/927.json::sample_08, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=557, analysis_length=557, decay_rate=1.07
# Sample 234: uid=test/precalculus/927.json::sample_09, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=743, analysis_length=743, decay_rate=1.08
# Sample 235: uid=test/precalculus/927.json::sample_10, question_uid=test/precalculus/927.json, success=False, score_accuracy=0.00, response_length=883, analysis_length=883, decay_rate=1.06
# Sample 236: uid=test/precalculus/927.json::sample_11, question_uid=test/precalculus/927.json, success=False, score_accuracy=0.00, response_length=881, analysis_length=881, decay_rate=1.08
# Sample 237: uid=test/precalculus/927.json::sample_12, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=691, analysis_length=691, decay_rate=1.08
# Sample 238: uid=test/precalculus/927.json::sample_13, question_uid=test/precalculus/927.json, success=False, score_accuracy=0.00, response_length=937, analysis_length=937, decay_rate=1.08
# Sample 239: uid=test/precalculus/927.json::sample_14, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=737, analysis_length=737, decay_rate=1.09
# Sample 240: uid=test/precalculus/927.json::sample_15, question_uid=test/precalculus/927.json, success=False, score_accuracy=0.00, response_length=1028, analysis_length=1028, decay_rate=1.09
# Sample 241: uid=test/precalculus/927.json::sample_16, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=621, analysis_length=621, decay_rate=1.06
# Sample 242: uid=test/precalculus/927.json::sample_17, question_uid=test/precalculus/927.json, success=False, score_accuracy=0.00, response_length=1144, analysis_length=1144, decay_rate=1.09
# Sample 243: uid=test/precalculus/927.json::sample_18, question_uid=test/precalculus/927.json, success=False, score_accuracy=0.00, response_length=1501, analysis_length=1501, decay_rate=1.10
# Sample 244: uid=test/precalculus/927.json::sample_19, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=706, analysis_length=706, decay_rate=1.08
# Sample 245: uid=test/precalculus/927.json::sample_20, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=679, analysis_length=679, decay_rate=1.08
# Sample 246: uid=test/precalculus/927.json::sample_21, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=699, analysis_length=699, decay_rate=1.08
# Sample 247: uid=test/precalculus/927.json::sample_22, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=789, analysis_length=789, decay_rate=1.08
# Sample 248: uid=test/precalculus/927.json::sample_23, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=827, analysis_length=827, decay_rate=1.05
# Sample 249: uid=test/precalculus/927.json::sample_24, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=643, analysis_length=643, decay_rate=1.08
# Sample 250: uid=test/precalculus/927.json::sample_25, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=732, analysis_length=732, decay_rate=1.07
# Sample 251: uid=test/precalculus/927.json::sample_26, question_uid=test/precalculus/927.json, success=False, score_accuracy=0.00, response_length=784, analysis_length=784, decay_rate=1.06
# Sample 252: uid=test/precalculus/927.json::sample_27, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=615, analysis_length=615, decay_rate=1.08
# Sample 253: uid=test/precalculus/927.json::sample_28, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=742, analysis_length=742, decay_rate=1.08
# Sample 254: uid=test/precalculus/927.json::sample_29, question_uid=test/precalculus/927.json, success=True, score_accuracy=1.00, response_length=759, analysis_length=759, decay_rate=1.07
# ...
# Sample 3116: uid=test/prealgebra/105.json::sample_12, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=251, analysis_length=251, decay_rate=0.99
# Sample 3117: uid=test/prealgebra/105.json::sample_13, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=238, analysis_length=238, decay_rate=1.00
# Sample 3118: uid=test/prealgebra/105.json::sample_14, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=217, analysis_length=217, decay_rate=0.99
# Sample 3119: uid=test/prealgebra/105.json::sample_15, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=212, analysis_length=212, decay_rate=0.96
# Sample 3120: uid=test/prealgebra/105.json::sample_16, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=226, analysis_length=226, decay_rate=0.96
# Sample 3121: uid=test/prealgebra/105.json::sample_17, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=266, analysis_length=266, decay_rate=0.99
# Sample 3122: uid=test/prealgebra/105.json::sample_18, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=243, analysis_length=243, decay_rate=1.01
# Sample 3123: uid=test/prealgebra/105.json::sample_19, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=210, analysis_length=210, decay_rate=0.95
# Sample 3124: uid=test/prealgebra/105.json::sample_20, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=238, analysis_length=238, decay_rate=0.96
# Sample 3125: uid=test/prealgebra/105.json::sample_21, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=240, analysis_length=240, decay_rate=0.96
# Sample 3126: uid=test/prealgebra/105.json::sample_22, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=246, analysis_length=246, decay_rate=1.01
# Sample 3127: uid=test/prealgebra/105.json::sample_23, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=285, analysis_length=285, decay_rate=1.00
# Sample 3128: uid=test/prealgebra/105.json::sample_24, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=271, analysis_length=271, decay_rate=1.01
# Sample 3129: uid=test/prealgebra/105.json::sample_25, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=205, analysis_length=205, decay_rate=0.98
# Sample 3130: uid=test/prealgebra/105.json::sample_26, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=195, analysis_length=195, decay_rate=0.96
# Sample 3131: uid=test/prealgebra/105.json::sample_27, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=256, analysis_length=256, decay_rate=0.95
# Sample 3132: uid=test/prealgebra/105.json::sample_28, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=214, analysis_length=214, decay_rate=0.94
# Sample 3133: uid=test/prealgebra/105.json::sample_29, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=219, analysis_length=219, decay_rate=0.98
# Sample 3134: uid=test/prealgebra/105.json::sample_30, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=243, analysis_length=243, decay_rate=1.02
# Sample 3135: uid=test/prealgebra/105.json::sample_31, question_uid=test/prealgebra/105.json, success=True, score_accuracy=1.00, response_length=221, analysis_length=221, decay_rate=0.96
# Sample 3136: uid=test/prealgebra/1924.json::sample_00, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=114, analysis_length=114, decay_rate=1.05
# Sample 3137: uid=test/prealgebra/1924.json::sample_01, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=134, analysis_length=134, decay_rate=1.05
# Sample 3138: uid=test/prealgebra/1924.json::sample_02, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=136, analysis_length=136, decay_rate=1.05
# Sample 3139: uid=test/prealgebra/1924.json::sample_03, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=136, analysis_length=136, decay_rate=1.08
# Sample 3140: uid=test/prealgebra/1924.json::sample_04, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=138, analysis_length=138, decay_rate=1.09
# Sample 3141: uid=test/prealgebra/1924.json::sample_05, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=116, analysis_length=116, decay_rate=1.09
# Sample 3142: uid=test/prealgebra/1924.json::sample_06, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=124, analysis_length=124, decay_rate=1.07
# Sample 3143: uid=test/prealgebra/1924.json::sample_07, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=131, analysis_length=131, decay_rate=1.06
# Sample 3144: uid=test/prealgebra/1924.json::sample_08, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=120, analysis_length=120, decay_rate=1.07
# Sample 3145: uid=test/prealgebra/1924.json::sample_09, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=120, analysis_length=120, decay_rate=1.07
# Sample 3146: uid=test/prealgebra/1924.json::sample_10, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=108, analysis_length=108, decay_rate=1.07
# Sample 3147: uid=test/prealgebra/1924.json::sample_11, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=121, analysis_length=121, decay_rate=1.10
# Sample 3148: uid=test/prealgebra/1924.json::sample_12, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=118, analysis_length=118, decay_rate=1.06
# Sample 3149: uid=test/prealgebra/1924.json::sample_13, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=126, analysis_length=126, decay_rate=1.07
# Sample 3150: uid=test/prealgebra/1924.json::sample_14, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=138, analysis_length=138, decay_rate=1.04
# Sample 3151: uid=test/prealgebra/1924.json::sample_15, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=108, analysis_length=108, decay_rate=1.06
# Sample 3152: uid=test/prealgebra/1924.json::sample_16, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=134, analysis_length=134, decay_rate=1.08
# Sample 3153: uid=test/prealgebra/1924.json::sample_17, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=135, analysis_length=135, decay_rate=1.10
# Sample 3154: uid=test/prealgebra/1924.json::sample_18, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=97, analysis_length=97, decay_rate=1.13
# Sample 3155: uid=test/prealgebra/1924.json::sample_19, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=124, analysis_length=124, decay_rate=1.09
# Sample 3156: uid=test/prealgebra/1924.json::sample_20, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=140, analysis_length=140, decay_rate=1.08
# Sample 3157: uid=test/prealgebra/1924.json::sample_21, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=112, analysis_length=112, decay_rate=1.05
# Sample 3158: uid=test/prealgebra/1924.json::sample_22, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=125, analysis_length=125, decay_rate=1.06
# Sample 3159: uid=test/prealgebra/1924.json::sample_23, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=119, analysis_length=119, decay_rate=1.09
# Sample 3160: uid=test/prealgebra/1924.json::sample_24, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=144, analysis_length=144, decay_rate=1.05
# Sample 3161: uid=test/prealgebra/1924.json::sample_25, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=120, analysis_length=120, decay_rate=1.10
# Sample 3162: uid=test/prealgebra/1924.json::sample_26, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=116, analysis_length=116, decay_rate=1.09
# Sample 3163: uid=test/prealgebra/1924.json::sample_27, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=119, analysis_length=119, decay_rate=1.08
# Sample 3164: uid=test/prealgebra/1924.json::sample_28, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=135, analysis_length=135, decay_rate=1.05
# Sample 3165: uid=test/prealgebra/1924.json::sample_29, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=139, analysis_length=139, decay_rate=1.05
# Sample 3166: uid=test/prealgebra/1924.json::sample_30, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=135, analysis_length=135, decay_rate=1.05
# Sample 3167: uid=test/prealgebra/1924.json::sample_31, question_uid=test/prealgebra/1924.json, success=True, score_accuracy=1.00, response_length=112, analysis_length=112, decay_rate=1.05
# Sample 3168: uid=test/precalculus/1300.json::sample_00, question_uid=test/precalculus/1300.json, success=False, score_accuracy=0.00, response_length=1041, analysis_length=1041, decay_rate=1.16
# Sample 3169: uid=test/precalculus/1300.json::sample_01, question_uid=test/precalculus/1300.json, success=False, score_accuracy=0.00, response_length=1077, analysis_length=1077, decay_rate=1.13
# Sample 3170: uid=test/precalculus/1300.json::sample_02, question_uid=test/precalculus/1300.json, success=False, score_accuracy=0.00, response_length=946, analysis_length=946, decay_rate=1.13
# Sample 3171: uid=test/precalculus/1300.json::sample_03, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=968, analysis_length=968, decay_rate=1.14
# Sample 3172: uid=test/precalculus/1300.json::sample_04, question_uid=test/precalculus/1300.json, success=False, score_accuracy=0.00, response_length=837, analysis_length=837, decay_rate=1.14
# Sample 3173: uid=test/precalculus/1300.json::sample_05, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=1114, analysis_length=1114, decay_rate=1.16
# Sample 3174: uid=test/precalculus/1300.json::sample_06, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=814, analysis_length=814, decay_rate=1.12
# Sample 3175: uid=test/precalculus/1300.json::sample_07, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=1066, analysis_length=1066, decay_rate=1.16
# Sample 3176: uid=test/precalculus/1300.json::sample_08, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=1026, analysis_length=1026, decay_rate=1.13
# Sample 3177: uid=test/precalculus/1300.json::sample_09, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=984, analysis_length=984, decay_rate=1.17
# Sample 3178: uid=test/precalculus/1300.json::sample_10, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=1720, analysis_length=1720, decay_rate=1.19
# Sample 3179: uid=test/precalculus/1300.json::sample_11, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=993, analysis_length=993, decay_rate=1.15
# Sample 3180: uid=test/precalculus/1300.json::sample_12, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=1047, analysis_length=1047, decay_rate=1.17
# Sample 3181: uid=test/precalculus/1300.json::sample_13, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=901, analysis_length=901, decay_rate=1.15
# Sample 3182: uid=test/precalculus/1300.json::sample_14, question_uid=test/precalculus/1300.json, success=False, score_accuracy=0.00, response_length=899, analysis_length=899, decay_rate=1.15
# Sample 3183: uid=test/precalculus/1300.json::sample_15, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=1016, analysis_length=1016, decay_rate=1.16
# Sample 3184: uid=test/precalculus/1300.json::sample_16, question_uid=test/precalculus/1300.json, success=False, score_accuracy=0.00, response_length=1048, analysis_length=1048, decay_rate=1.14
# Sample 3185: uid=test/precalculus/1300.json::sample_17, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=1080, analysis_length=1080, decay_rate=1.14
# Sample 3186: uid=test/precalculus/1300.json::sample_18, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=908, analysis_length=908, decay_rate=1.15
# Sample 3187: uid=test/precalculus/1300.json::sample_19, question_uid=test/precalculus/1300.json, success=False, score_accuracy=0.00, response_length=953, analysis_length=953, decay_rate=1.19
# Sample 3188: uid=test/precalculus/1300.json::sample_20, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=963, analysis_length=963, decay_rate=1.13
# Sample 3189: uid=test/precalculus/1300.json::sample_21, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=963, analysis_length=963, decay_rate=1.14
# Sample 3190: uid=test/precalculus/1300.json::sample_22, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=958, analysis_length=958, decay_rate=1.14
# Sample 3191: uid=test/precalculus/1300.json::sample_23, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=866, analysis_length=866, decay_rate=1.14
# Sample 3192: uid=test/precalculus/1300.json::sample_24, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=1074, analysis_length=1074, decay_rate=1.16
# Sample 3193: uid=test/precalculus/1300.json::sample_25, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=1141, analysis_length=1141, decay_rate=1.13
# Sample 3194: uid=test/precalculus/1300.json::sample_26, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=1009, analysis_length=1009, decay_rate=1.15
# Sample 3195: uid=test/precalculus/1300.json::sample_27, question_uid=test/precalculus/1300.json, success=False, score_accuracy=0.00, response_length=907, analysis_length=907, decay_rate=1.16
# Sample 3196: uid=test/precalculus/1300.json::sample_28, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=945, analysis_length=945, decay_rate=1.18
# Sample 3197: uid=test/precalculus/1300.json::sample_29, question_uid=test/precalculus/1300.json, success=False, score_accuracy=0.00, response_length=1068, analysis_length=1068, decay_rate=1.18
# Sample 3198: uid=test/precalculus/1300.json::sample_30, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=938, analysis_length=938, decay_rate=1.14
# Sample 3199: uid=test/precalculus/1300.json::sample_31, question_uid=test/precalculus/1300.json, success=True, score_accuracy=1.00, response_length=922, analysis_length=922, decay_rate=1.09
# Prepared 3199 samples with valid eigenspectra

# %%
def summarize(values):
    arr = np.asarray(values, dtype=np.float64)
    return {
        'n': int(arr.size),
        'mean': float(arr.mean()) if arr.size else None,
        'std': float(arr.std()) if arr.size else None,
        'min': float(arr.min()) if arr.size else None,
        'max': float(arr.max()) if arr.size else None,
    }

success_decay = [s['decay_rate'] for s in samples if s['success']]
failure_decay = [s['decay_rate'] for s in samples if not s['success']]
print('Success decay stats:', summarize(success_decay))
print('Failure decay stats:', summarize(failure_decay))
# Out:
# Success decay stats: {'n': 2627, 'mean': 1.0913586218728328, 'std': 0.06234399528608034, 'min': 0.9031760734378166, 'max': 1.295990884201502}
# Failure decay stats: {'n': 572, 'mean': 1.144455745103605, 'std': 0.058577999233070575, 'min': 0.9837614287352184, 'max': 1.3244400340978304}

# %%
plt.figure(figsize=(7, 5))
if failure_decay:
    plt.hist(failure_decay, bins=30, alpha=0.7, label='failure', color='#d1495b')
if success_decay:
    plt.hist(success_decay, bins=30, alpha=0.7, label='success', color='#2a9d8f')
plt.xlabel('Power-law eigenspectrum decay exponent')
plt.ylabel('count')
plt.title('Trajectory covariance power-law spectrum decay')
plt.legend()
plt.grid(alpha=0.2)
plt.show()

# %%
# 2D plot: x = decay rate, y = success indicator with jitter.
x = np.asarray([s['decay_rate'] for s in samples], dtype=np.float64)
y = np.asarray([1.0 if s['success'] else 0.0 for s in samples], dtype=np.float64)
y_jitter = y + np.random.uniform(-0.06, 0.06, size=len(y))

plt.figure(figsize=(8, 5))
colors = np.where(y > 0.5, '#2a9d8f', '#d1495b')
plt.scatter(x, y_jitter, c=colors, s=18, alpha=0.55)
plt.yticks([0, 1], ['failure', 'success'])
plt.xlabel('Power-law eigenspectrum decay exponent')
plt.ylabel('Outcome')
plt.title('Success vs covariance spectrum decay rate')
plt.grid(alpha=0.2)
plt.show()

# %%
# Bin by decay rate and compute empirical success rate.
def binned_success_rate(samples, n_bins=20):
    x = np.asarray([s['decay_rate'] for s in samples], dtype=np.float64)
    y = np.asarray([1.0 if s['success'] else 0.0 for s in samples], dtype=np.float64)
    edges = np.linspace(x.min(), x.max(), n_bins + 1)
    centers = 0.5 * (edges[:-1] + edges[1:])
    rates = []
    counts = []
    for lo, hi in zip(edges[:-1], edges[1:]):
        mask = (x >= lo) & (x < hi)
        if mask.any():
            rates.append(float(y[mask].mean()))
            counts.append(int(mask.sum()))
        else:
            rates.append(np.nan)
            counts.append(0)
    return centers, np.asarray(rates), np.asarray(counts)

centers, rates, counts = binned_success_rate(samples, n_bins=20)

plt.figure(figsize=(8, 5))
plt.plot(centers, rates, marker='o', color='#264653')
plt.xlabel('Power-law eigenspectrum decay exponent')
plt.ylabel('Empirical success rate')
plt.title('Success rate vs power-law spectrum decay exponent')
plt.ylim(-0.05, 1.05)
plt.grid(alpha=0.2)
plt.show()

print('Bin counts:', counts)
# Out:
# Bin counts: [  7  30  68  46  69 173 297 376 405 393 342 322 243 235 107  52  23   6
#    3   1]

# %% [markdown]
# ## Success vs Failure Test Statistic
#
# This section compares the decay-exponent distributions for successful and failed trajectories and reports simple effect statistics.

# %%
def cliffs_delta(x, y):
    x = np.asarray(x, dtype=np.float64)
    y = np.asarray(y, dtype=np.float64)
    if x.size == 0 or y.size == 0:
        return None
    total = 0
    for xv in x:
        total += np.sum(xv > y) - np.sum(xv < y)
    return float(total / (x.size * y.size))


def permutation_mean_diff(x, y, n_perm=2000, seed=1):
    x = np.asarray(x, dtype=np.float64)
    y = np.asarray(y, dtype=np.float64)
    observed = float(x.mean() - y.mean())
    pooled = np.concatenate([x, y])
    rng = np.random.default_rng(seed)
    count = 0
    for _ in range(n_perm):
        rng.shuffle(pooled)
        xp = pooled[:x.size]
        yp = pooled[x.size:]
        diff = xp.mean() - yp.mean()
        if abs(diff) >= abs(observed):
            count += 1
    p = (count + 1) / (n_perm + 1)
    return observed, p

success_arr = np.asarray(success_decay, dtype=np.float64)
failure_arr = np.asarray(failure_decay, dtype=np.float64)
print('mean(success) - mean(failure):', float(success_arr.mean() - failure_arr.mean()))
print('cliffs_delta(success, failure):', cliffs_delta(success_arr, failure_arr))
obs, pval = permutation_mean_diff(success_arr, failure_arr, n_perm=2000, seed=RANDOM_SEED)
print('permutation test mean diff:', obs)
print('permutation p-value:', pval)
# Out:
# mean(success) - mean(failure): -0.0530971232307722
# cliffs_delta(success, failure): -0.46423903466156985
# permutation test mean diff: -0.0530971232307722
# permutation p-value: 0.0004997501249375312

# %%
# Show a few example eigenspectra.
interesting = []
interesting.extend(sorted([s for s in samples if s['success']], key=lambda s: s['decay_rate'])[:2])
interesting.extend(sorted([s for s in samples if s['success']], key=lambda s: -s['decay_rate'])[:2])
interesting.extend(sorted([s for s in samples if not s['success']], key=lambda s: s['decay_rate'])[:2])
interesting.extend(sorted([s for s in samples if not s['success']], key=lambda s: -s['decay_rate'])[:2])

plt.figure(figsize=(8, 6))
for item in interesting[:8]:
    vals = item['top_eigvals']
    xs = np.arange(1, len(vals) + 1)
    label = f"{'S' if item['success'] else 'F'} decay={item['decay_rate']:.3f}"
    plt.plot(xs, vals, alpha=0.7, label=label)
plt.yscale('log')
plt.xlabel('Eigenvalue rank')
plt.ylabel('Eigenvalue (log scale)')
plt.title('Example covariance eigenspectra')
plt.grid(alpha=0.2)
plt.legend(fontsize=8)
plt.show()

# %%
# Optional: aggregate by question_uid and compare question-level success rate to average decay rate.
by_question = {}
for item in samples:
    by_question.setdefault(item['question_uid'], []).append(item)

question_rows = []
for qid, group in by_question.items():
    question_rows.append({
        'question_uid': qid,
        'n_samples': len(group),
        'success_rate': float(np.mean([1.0 if x['success'] else 0.0 for x in group])),
        'mean_decay_rate': float(np.mean([x['decay_rate'] for x in group])),
        'std_decay_rate': float(np.std([x['decay_rate'] for x in group])),
    })

qx = np.asarray([r['mean_decay_rate'] for r in question_rows], dtype=np.float64)
qy = np.asarray([r['success_rate'] for r in question_rows], dtype=np.float64)

plt.figure(figsize=(8, 5))
plt.scatter(qx, qy, s=24, alpha=0.7, c='#577590')
plt.xlabel('Mean power-law decay exponent over samples for a question')
plt.ylabel('Per-question success rate')
plt.title('Question-level success rate vs mean power-law decay exponent')
plt.grid(alpha=0.2)
plt.show()

# %% [markdown]
# ## Grouped By Question
#
# This section uses the multi-sample setup to summarize decay exponents per `question_uid`, then relates within-question success rate to the question-level mean and spread of the decay exponent.

# %%
by_question = {}
for item in samples:
    by_question.setdefault(item['question_uid'], []).append(item)

question_rows = []
for qid, group in by_question.items():
    succ = np.asarray([1.0 if x['success'] else 0.0 for x in group], dtype=np.float64)
    dec = np.asarray([x['decay_rate'] for x in group], dtype=np.float64)
    question_rows.append({
        'question_uid': qid,
        'n_samples': len(group),
        'success_rate': float(succ.mean()),
        'mean_decay_rate': float(dec.mean()),
        'std_decay_rate': float(dec.std()),
        'success_mean_decay': float(dec[succ > 0.5].mean()) if np.any(succ > 0.5) else np.nan,
        'failure_mean_decay': float(dec[succ < 0.5].mean()) if np.any(succ < 0.5) else np.nan,
    })

print('Question-level mean decay stats:', summarize([r['mean_decay_rate'] for r in question_rows]))
print('Question-level std decay stats:', summarize([r['std_decay_rate'] for r in question_rows]))

qx = np.asarray([r['mean_decay_rate'] for r in question_rows], dtype=np.float64)
qy = np.asarray([r['success_rate'] for r in question_rows], dtype=np.float64)
qstd = np.asarray([r['std_decay_rate'] for r in question_rows], dtype=np.float64)

fig, axes = plt.subplots(1, 2, figsize=(13, 5))
axes[0].scatter(qx, qy, s=24, alpha=0.7, c='#577590')
axes[0].set_xlabel('Mean power-law decay exponent over samples for a question')
axes[0].set_ylabel('Per-question success rate')
axes[0].set_title('Question success rate vs mean decay exponent')
axes[0].grid(alpha=0.2)

axes[1].scatter(qstd, qy, s=24, alpha=0.7, c='#b56576')
axes[1].set_xlabel('Std of power-law decay exponent within a question')
axes[1].set_ylabel('Per-question success rate')
axes[1].set_title('Question success rate vs within-question decay spread')
axes[1].grid(alpha=0.2)
plt.tight_layout()
plt.show()
# Out:
# Question-level mean decay stats: {'n': 100, 'mean': 1.1008367849527831, 'std': 0.060266004767106314, 'min': 0.945144236325725, 'max': 1.2249103183701444}
# Question-level std decay stats: {'n': 100, 'mean': 0.02233768783166184, 'std': 0.009376693074111165, 'min': 0.006132115978032904, 'max': 0.07087541841458961}
